# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7]
y=[3,4,5,6,7,8,9]
plt.bar(x,y)
# Out:
# <BarContainer object of 7 artists>

# %%
x=[12,33,55,66,99]
y=[44,55,22,77,86]
plt.pie(x)
plt.show()
plt.pie(y)
plt.show()
